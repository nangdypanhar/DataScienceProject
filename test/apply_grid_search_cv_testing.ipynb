# %%
import pandas as pd

df = pd.read_csv('encoded_diabetes_data.csv')
print(df.keys())
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level',
#        'blood_glucose_level', 'diabetes', 'smoking_history_encoded',
#        'gender_encoded'],
#       dtype='object')

# %%
# Extract features (X) – everything except the target column
df_feat = df.drop(columns=['diabetes'])

# Extract target (y) – the column we want to predict
df_target = df[['diabetes']]

print("Feature Variables: ")
print(df_feat.info())  

print("\nTarget Variable: ")
print(df_target.value_counts())
# Out:
# Feature Variables:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14618 entries, 0 to 14617
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      14618 non-null  float64
#  1   hypertension             14618 non-null  int64
#  2   heart_disease            14618 non-null  int64
#  3   bmi                      14618 non-null  float64
#  4   HbA1c_level              14618 non-null  float64
#  5   blood_glucose_level      14618 non-null  int64
#  6   smoking_history_encoded  14618 non-null  int64
#  7   gender_encoded           14618 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 913.8 KB
# None
#
# Target Variable:
# diabetes
# 0           10000
# 1            4618
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split 
import numpy as np 
 
X_train, X_test, y_train, y_test = train_test_split( 
                        df_feat, np.ravel(df_target), 
                test_size = 0.30, random_state = 101)

# %%
from sklearn.svm import SVC 
from sklearn.metrics import classification_report, confusion_matrix
# train the model on train set 
model = SVC() 
model.fit(X_train, y_train) 
  
# print prediction results 
predictions = model.predict(X_test) 
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87      3002
#            1       0.74      0.68      0.71      1384
#
#     accuracy                           0.82      4386
#    macro avg       0.80      0.78      0.79      4386
# weighted avg       0.82      0.82      0.82      4386

# %%
# apply GridSearchCV
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score

# common hyperparameters to tune
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
grid.fit(X_train, y_train)

# print best parameter after tuning 
print(grid.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_) 

grid_predictions = grid.predict(X_test) 
  
# print classification report 
print(classification_report(y_test, grid_predictions))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.684 total time=   7.1s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.684 total time=   4.1s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.684 total time=   4.4s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.684 total time=   3.8s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.684 total time=   3.7s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.749 total time=   2.6s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.744 total time=   2.6s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.746 total time=   2.6s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.750 total time=   2.7s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.742 total time=   2.7s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.823 total time=   1.4s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.825 total time=   1.4s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.827 total time=   1.4s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.821 total time=   1.4s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.826 total time=   1.3s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.820 total time=   1.1s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.818 total time=   1.2s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.820 total time=   1.2s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.825 total time=   1.1s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.822 total time=   1.2s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.794 total time=   1.3s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.796 total time=   1.3s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.801 total time=   1.4s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.803 total time=   1.4s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.797 total time=   1.4s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.712 total time=   4.5s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.706 total time=   4.5s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.713 total time=   4.7s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.714 total time=   8.7s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.714 total time=   9.1s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.851 total time=   4.9s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.848 total time=   5.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.862 total time=   5.5s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.853 total time=   6.9s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.853 total time=   5.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.862 total time=   2.3s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.857 total time=   1.7s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.866 total time=   1.8s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.860 total time=   1.9s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.862 total time=   2.5s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.863 total time=   3.5s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.859 total time=   3.5s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.863 total time=   3.8s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.859 total time=   4.6s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.858 total time=   3.6s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.840 total time=   4.2s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.839 total time=   3.8s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.841 total time=   4.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.844 total time=   4.2s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.842 total time=   4.4s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.730 total time=  24.4s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.712 total time=   7.6s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.725 total time=   6.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.717 total time=   6.2s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.727 total time=   6.4s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.829 total time=   2.5s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.830 total time=   2.4s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.839 total time=   2.4s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.830 total time=   2.5s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.839 total time=   2.5s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.875 total time=   1.3s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.865 total time=   1.3s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.877 total time=   1.3s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.876 total time=   1.3s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.867 total time=   1.2s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.873 total time=   0.9s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.869 total time=   0.8s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.879 total time=   0.8s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.875 total time=   0.9s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.867 total time=   0.9s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.866 total time=   0.9s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.870 total time=   0.8s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.883 total time=   0.9s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.869 total time=   0.8s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.870 total time=   0.9s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.729 total time=   6.2s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.709 total time=   6.3s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.724 total time=   6.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.716 total time=   6.2s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.724 total time=   6.6s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.811 total time=   3.4s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.809 total time=   3.3s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.807 total time=   3.3s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.807 total time=   3.5s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.817 total time=   3.3s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.868 total time=   2.5s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.855 total time=   2.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.869 total time=   2.3s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.868 total time=   2.2s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.865 total time=   2.5s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.872 total time=   1.3s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.868 total time=   1.2s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.887 total time=   1.2s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.873 total time=   1.2s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.868 total time=   1.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.874 total time=   0.9s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.872 total time=   1.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.885 total time=   1.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.877 total time=   0.9s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.870 total time=   0.9s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.730 total time=   6.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.707 total time=   6.1s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.722 total time=   6.1s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.716 total time=   5.9s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.725 total time=   7.9s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.807 total time=   7.2s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.805 total time=   4.7s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.801 total time=   9.4s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.802 total time=  16.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.807 total time=  15.9s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.845 total time=  31.3s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.842 total time=  21.6s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.856 total time=  25.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.866 total time=  35.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.848 total time=  28.6s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.868 total time=   5.4s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.867 total time=   4.6s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.885 total time=   4.3s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.876 total time=   4.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.869 total time=   4.6s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.872 total time=   2.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.873 total time=   2.1s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.884 total time=   2.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.878 total time=   2.4s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.870 total time=   1.8s
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=100, gamma=0.0001)
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      3002
#            1       0.81      0.79      0.80      1384
#
#     accuracy                           0.87      4386
#    macro avg       0.86      0.85      0.85      4386
# weighted avg       0.87      0.87      0.87      4386
